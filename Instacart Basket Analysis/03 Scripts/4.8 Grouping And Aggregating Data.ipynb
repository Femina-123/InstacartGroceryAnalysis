# %% [markdown]
# ### Import Libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Import Data

# %%
# Define path
path = r'C:\Users\Lukman\OneDrive\Documents\FEMINA CF\Data Immerssion\Achievement4\Instacart Basket Analysis'

# %%
# Import data set
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merged_derived.pkl'))

# %% [markdown]
# ### Grouping Data

# %%
# create a subset

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id    prices  \
# 0           1  Chocolate Sandwich Cookies        61             19  5.800781
# 1           1  Chocolate Sandwich Cookies        61             19  5.800781
# 2           1  Chocolate Sandwich Cookies        61             19  5.800781
# 3           1  Chocolate Sandwich Cookies        61             19  5.800781
# 4           1  Chocolate Sandwich Cookies        61             19  5.800781
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
# grouping by using groupby() function and agg() function

df.groupby(['department_id']).agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# Grouping without agg() function

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
# Use groupby and agg functions to calculate mean of user_order_number
ords_prods_merge.groupby(['department_id']).agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# The mean of the entire dataset  is slightly higher than the subset . This indicates that, on average, the entire dataset has a slightly higher mean order number compared to the subset.

# %% [markdown]
# ### Performing Multiple Aggregation

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# ### Aggregating data with transform() function.

# %%
# a new column called “max_order” is created, which will be what stores the maximum order number for each user

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# View updated data frame
ords_prods_merge.head(20)
# Out:
#     product_id                product_name  aisle_id  department_id    prices  \
# 0            1  Chocolate Sandwich Cookies        61             19  5.800781
# 1            1  Chocolate Sandwich Cookies        61             19  5.800781
# 2            1  Chocolate Sandwich Cookies        61             19  5.800781
# 3            1  Chocolate Sandwich Cookies        61             19  5.800781
# 4            1  Chocolate Sandwich Cookies        61             19  5.800781
# 5            1  Chocolate Sandwich Cookies        61             19  5.800781
# 6            1  Chocolate Sandwich Cookies        61             19  5.800781
# 7            1  Chocolate Sandwich Cookies        61             19  5.800781
# 8            1  Chocolate Sandwich Cookies        61             19  5.800781
# 9            1  Chocolate Sandwich Cookies        61             19  5.800781
# 10           1  Chocolate Sandwich Cookies        61             19  5.800781
# ...

# %% [markdown]
# ### Deriving Columns with loc()

# %%
# Use loc function to make loyalty flag column with given criteria
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check frequency of values in new loyalty flag column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#if you wanted to write a head() function that returned the first 60 rows of only the “user_id,” “loyalty_flag,” and “order_number” columns

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6

# %% [markdown]
# ### Different types of spenders in their marketing campaigns.

# %%
# Creating a new column for 'average_spend'
ords_prods_merge['average_spend']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Create flag for low spender.
ords_prods_merge.loc[ords_prods_merge['average_spend']<10,'spender_flag']='Low_spender'

# %%
# create flag for high spender.
ords_prods_merge.loc[ords_prods_merge['average_spend']>= 10, 'spender_flag'] = 'High_spender'

# %%
# Check spender flags
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# Low_spender     31770219
# High_spender      575296
# NaN                59344
# Name: spender_flag, dtype: int64

# %%
# check the output
ords_prods_merge[['user_id', 'average_spend', 'spender_flag', 'prices']].head(20)
# Out:
#     user_id  average_spend spender_flag    prices
# 0       138       6.937500  Low_spender  5.800781
# 1       138       6.937500  Low_spender  5.800781
# 2       709       7.929688  Low_spender  5.800781
# 3       764       4.972656  Low_spender  5.800781
# 4       764       4.972656  Low_spender  5.800781
# 5       777       6.933594  Low_spender  5.800781
# 6       825       5.957031  Low_spender  5.800781
# 7       910       6.679688  Low_spender  5.800781
# 8      1052       7.164062  Low_spender  5.800781
# 9      1052       7.164062  Low_spender  5.800781
# 10     1379       5.812500  Low_spender  5.800781
# 11     1480       5.082031  Low_spender  5.800781
# 12     1480       5.082031  Low_spender  5.800781
# 13     1480       5.082031  Low_spender  5.800781
# 14     1494       6.804688  Low_spender  5.800781
# 15     1494       6.804688  Low_spender  5.800781
# 16     1494       6.804688  Low_spender  5.800781
# 17     1540       6.605469  Low_spender  5.800781
# ...

# %% [markdown]
# ### Determine frequent versus non-frequent customers.

# %%
# Create a new column for frequent users
ords_prods_merge['Customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Creating flag on order frequency
ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] > 20, 'frequency_flag'] = 'Non_frequent_customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['Customer_frequency']>10) & (ords_prods_merge['Customer_frequency']<=20),'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent Customer        22790523
# Regular customer          6927608
# Non_frequent_customer     2686728
# Name: frequency_flag, dtype: int64

# %%
# check the output
ords_prods_merge[['user_id','days_since_prior_order', 'Customer_frequency', 'frequency_flag']].head(20)
# Out:
#     user_id  days_since_prior_order  Customer_frequency     frequency_flag
# 0       138                     3.0                 8.0  Frequent Customer
# 1       138                    20.0                 8.0  Frequent Customer
# 2       709                     6.0                 7.0  Frequent Customer
# 3       764                     7.0                 9.0  Frequent Customer
# 4       764                     9.0                 9.0  Frequent Customer
# 5       777                    26.0                11.0   Regular customer
# 6       825                    30.0                19.0   Regular customer
# 7       910                    30.0                 6.0  Frequent Customer
# 8      1052                    19.0                 9.5  Frequent Customer
# 9      1052                    15.0                 9.5  Frequent Customer
# 10     1379                     7.0                20.0   Regular customer
# ...

# %% [markdown]
# ### Export Dataframe

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_aggregated.pkl'))
